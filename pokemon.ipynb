# %%
import pandas as pd
from sqlalchemy import create_engine
from random import randint

# %%
moves_file = "./Resources/move-data.csv"
pokemon_file = "./Resources/pokemon-data.csv"

# %%
moves_df = pd.read_csv(moves_file)
pokemon_df = pd.read_csv(pokemon_file, sep=';')

# %%
moves_df.head()
# Out:
#    Index         Name      Type  Category Contest  PP Power Accuracy  \
# 0      1        Pound    Normal  Physical   Tough  35    40      100
# 1      2  Karate Chop  Fighting  Physical   Tough  25    50      100
# 2      3  Double Slap    Normal  Physical    Cute  10    15       85
# 3      4  Comet Punch    Normal  Physical   Tough  15    18       85
# 4      5   Mega Punch    Normal  Physical   Tough  20    80       85
#
#    Generation
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1

# %%
pokemon_df.head()
# Out:
#              Name             Types  \
# 0       Abomasnow  ['Grass', 'Ice']
# 1  Abomasnow-Mega  ['Grass', 'Ice']
# 2            Abra       ['Psychic']
# 3           Absol          ['Dark']
# 4      Absol-Mega          ['Dark']
#
#                                        Abilities  Tier  HP  Attack  Defense  \
# 0                 ['Snow Warning', 'Soundproof']    PU  90      92       75
# 1                               ['Snow Warning']  NUBL  90     132      105
# 2  ['Inner Focus', 'Magic Guard', 'Synchronize']    LC  25      20       15
# 3        ['Justified', 'Pressure', 'Super Luck']    PU  65     130       60
# 4                               ['Magic Bounce']  RUBL  65     150       60
#
#    Special Attack  Special Defense  Speed Next Evolution(s)  \
# 0              92               85     60                []
# 1             132              105     30                []
# 2             105               55     90       ['Kadabra']
# 3              75               60     75                []
# 4             115               60    115                []
#
#                                                Moves
# 0  ['Ice Punch', 'Powder Snow', 'Leer', 'Razor Le...
# 1  ['Ice Punch', 'Powder Snow', 'Leer', 'Razor Le...
# 2  ['Teleport', 'Ally Switch', 'Barrier', 'Encore...
# 3  ['Perish Song', 'Future Sight', 'Me First', 'R...
# 4  ['Perish Song', 'Future Sight', 'Me First', 'R...

# %% [markdown]
# ### Transform Pokemon DataFrame

# %%
# List conversion function. Let me know if there are any issues
def convert(s):
    lst = []
    temp = str(s).split(", ")
    
    for x in temp:
        lst.append(x.translate({ord(i): None for i in "[']"}))
    
    return lst

# %%
pokemon_lst_df = pokemon_df.copy()
for i in range(0, len(pokemon_lst_df)):
    pokemon_lst_df.at[i,'Types'] = convert(pokemon_df.loc[i,'Types'])
    pokemon_lst_df.at[i,'Moves'] = convert(pokemon_df.loc[i,'Moves'])

# %%
pokemon_cols = ["Name", "Tier", "HP", "Attack", "Defense", "Special Attack", "Special Defense", "Speed"]
pokemon_trans_df = pokemon_lst_df[pokemon_cols].copy()
pokemon_trans_df = pokemon_trans_df.rename(columns={"Special Attack": "Special_Attack", "Special Defense": "Special_Defense"})

pokemon_trans_df['Type_1'] = ''
pokemon_trans_df['Type_2'] = 'None'
# Rename the column headers
for index, row in pokemon_lst_df.iterrows():
    for i in range(0, len(row['Types'])):
        pokemon_trans_df.loc[index,f'Type_{i+1}'] = row['Types'][i]
    pokemon_trans_df.loc[index,'Move'] = row['Moves'][randint(0,len(row['Moves'])-1)]

pokemon_trans_df.head()
# Out:
#              Name  Tier  HP  Attack  Defense  Special_Attack  Special_Defense  \
# 0       Abomasnow    PU  90      92       75              92               85
# 1  Abomasnow-Mega  NUBL  90     132      105             132              105
# 2            Abra    LC  25      20       15             105               55
# 3           Absol    PU  65     130       60              75               60
# 4      Absol-Mega  RUBL  65     150       60             115               60
#
#    Speed   Type_1 Type_2          Move
# 0     60    Grass    Ice      Blizzard
# 1     30    Grass    Ice     Avalanche
# 2     90  Psychic   None   Charge Beam
# 3     75     Dark   None   Dream Eater
# 4    115     Dark   None  Future Sight

# %% [markdown]
# ### Transform Pokemon DataFrame

# %%
moves_cols = ["Name", "Type", "Category", "PP", "Power", "Accuracy"]
moves_trans_df = moves_df[moves_cols].copy()
moves_trans_df = moves_trans_df.rename(columns={"Name": "Move", "Type": "Move_Type"})

# %% [markdown]
# ### Join Dataframes on Move

# %%
combined_df = pokemon_trans_df.merge(moves_trans_df, how = 'left', on = "Move")
combined_df.set_index('Name', inplace = True)
combined_df.head()
# Out:
#                 Tier  HP  Attack  Defense  Special_Attack  Special_Defense  \
# Name
# Abomasnow         PU  90      92       75              92               85
# Abomasnow-Mega  NUBL  90     132      105             132              105
# Abra              LC  25      20       15             105               55
# Absol             PU  65     130       60              75               60
# Absol-Mega      RUBL  65     150       60             115               60
#
#                 Speed   Type_1 Type_2          Move Move_Type  Category    PP  \
# Name
# Abomasnow          60    Grass    Ice      Blizzard       Ice   Special   5.0
# Abomasnow-Mega     30    Grass    Ice     Avalanche       Ice  Physical  10.0
# Abra               90  Psychic   None   Charge Beam  Electric   Special  10.0
# Absol              75     Dark   None   Dream Eater   Psychic   Special  15.0
# Absol-Mega        115     Dark   None  Future Sight   Psychic   Special  10.0
#
#                Power Accuracy
# Name
# Abomasnow        110     None
# Abomasnow-Mega    60      100
# Abra              50       90
# Absol            100      100
# Absol-Mega       120     None

# %% [markdown]
# ### Create database connection

# %%
connection_string = "postgres:Gabriel(00)@localhost:5432/Pokemon"
engine = create_engine(f'postgresql://{connection_string}')

# %%
# Confirm tables
engine.table_names()
# Out:
# ['pokemon']

# %% [markdown]
# ### Load DataFrames into database

# %%
combined_df.to_sql(name='pokemon', con=engine, if_exists='append', index=True)
